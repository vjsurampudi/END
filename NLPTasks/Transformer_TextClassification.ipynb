# %% [markdown]
# ## Using Transformer for Classification
# - Only encoder part of Transformer model is used for classification
# - No residual connection, no layer normalization
# - No need for masking
# - Multihead attention and positionwise feedforward network to extract features
# - Then, linear layer to get logits
#
# ## Implementation Details
# - N = 1, i.e. one layer is used
# - d_model = 256
# - maximum sequence lenght = 60
# - Adam optimizer is used with initial learning rate 0.0003. Reducing by half every 1/3 epochs.

# %% [markdown]
# ## Import Libraries

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
from torchtext import data
import spacy
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import copy
import math
import sys
from copy import deepcopy

# %% [markdown]
# ## Dataset Class
#
# Based on [AG News Dataset.](http://groups.di.unipi.it/~gulli/AG_corpus_of_news_articles.html)
#
# Example:
# ```
# __label__2 , brown in line after livingston sack preston , livingston have sacked allan preston as manager . the former hearts and st johnstone defender and his assistant , alan kernaghan , were dismissed after a run of seven defeats left the club
# __label__4 , lockheed profit jumps on it , jet demand , &lt p&gt \&lt /p&gt &lt p&gt new york ( reuters ) - no . 1 u . s . defense contractor lockheed\martin corp . &lt lmt . n&gt reported a 41 percent rise in quarterly\profit on tuesday , beating wall street forecasts , as demand\soared for its combat aircraft and information technology\services . &lt /p&gt
# __label__3 , japan narrowly escapes recession , new figures show japan ' s economy is barely staying out of recession with annual growth of just 0 . 2 in the third quarter .
# __label__4 , tiny telescope detects a giant planet , a tiny telescope has spotted a giant planet circling a faraway star , using a technique that could open a new phase of planetary discovery , scientists say .
# __label__3 , news corp . net profit soars 27 , news corp . saw healthy gains in profit and revenue in the fiscal first quarter - helped by growth in advertising at the fox news channel and the fox broadcast network , as
# ```

# %%
class Dataset(object):
    def __init__(self, config):
        self.config = config
        self.train_iterator = None
        self.test_iterator = None
        self.val_iterator = None
        self.vocab = []
        self.word_embeddings = {}
    
    def parse_label(self, label):
        '''
        Get the actual labels from label string
        Input:
            label (string) : labels of the form '__label__2'
        Returns:
            label (int) : integer value corresponding to label string
        '''
        return int(label.strip()[-1])

    def get_pandas_df(self, filename):
        '''
        Load the data into Pandas.DataFrame object
        This will be used to convert data to torchtext object
        '''
        with open(filename, 'r') as datafile:     
            data = [line.strip().split(',', maxsplit=1) for line in datafile]
            data_text = list(map(lambda x: x[1], data))
            data_label = list(map(lambda x: self.parse_label(x[0]), data))

        full_df = pd.DataFrame({"text":data_text, "label":data_label})
        return full_df
    
    def load_data(self, train_file, test_file=None, val_file=None):
        '''
        Loads the data from files
        Sets up iterators for training, validation and test data
        Also create vocabulary and word embeddings based on the data
        
        Inputs:
            train_file (String): path to training file
            test_file (String): path to test file
            val_file (String): path to validation file
        '''

        NLP = spacy.load('en')
        tokenizer = lambda sent: [x.text for x in NLP.tokenizer(sent) if x.text != " "]
        
        # Creating Field for data
        TEXT = data.Field(sequential=True, tokenize=tokenizer, lower=True, fix_length=self.config.max_sen_len)
        LABEL = data.Field(sequential=False, use_vocab=False)
        datafields = [("text",TEXT),("label",LABEL)]
        
        # Load data from pd.DataFrame into torchtext.data.Dataset
        train_df = self.get_pandas_df(train_file)
        train_examples = [data.Example.fromlist(i, datafields) for i in train_df.values.tolist()]
        train_data = data.Dataset(train_examples, datafields)
        
        test_df = self.get_pandas_df(test_file)
        test_examples = [data.Example.fromlist(i, datafields) for i in test_df.values.tolist()]
        test_data = data.Dataset(test_examples, datafields)
        
        # If validation file exists, load it. Otherwise get validation data from training data
        if val_file:
            val_df = self.get_pandas_df(val_file)
            val_examples = [data.Example.fromlist(i, datafields) for i in val_df.values.tolist()]
            val_data = data.Dataset(val_examples, datafields)
        else:
            train_data, val_data = train_data.split(split_ratio=0.8)
        
        TEXT.build_vocab(train_data)
        self.vocab = TEXT.vocab
        
        self.train_iterator = data.BucketIterator(
            (train_data),
            batch_size=self.config.batch_size,
            sort_key=lambda x: len(x.text),
            repeat=False,
            shuffle=True)
        
        self.val_iterator, self.test_iterator = data.BucketIterator.splits(
            (val_data, test_data),
            batch_size=self.config.batch_size,
            sort_key=lambda x: len(x.text),
            repeat=False,
            shuffle=False)
        
        print ("Loaded {} training examples".format(len(train_data)))
        print ("Loaded {} test examples".format(len(test_data)))
        print ("Loaded {} validation examples".format(len(val_data)))

# %% [markdown]
# ## Define the Model

# %%
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %%
class Embeddings(nn.Module):
    '''
    Usual Embedding layer with weights multiplied by sqrt(d_model)
    '''
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() *
                             -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(torch.as_tensor(position.numpy() * div_term.unsqueeze(0).numpy()))
        pe[:, 1::2] = torch.cos(torch.as_tensor(position.numpy() * div_term.unsqueeze(0).numpy()))#torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
def attention(query, key, value, mask=None, dropout=None):
    "Implementation of Scaled dot product attention"
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        "Take in model size and number of heads."
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        # We assume d_v always equals d_k
        self.d_k = d_model // h
        self.h = h
        self.linears = clones(nn.Linear(d_model, d_model), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        "Implements Multi-head attention"
        if mask is not None:
            # Same mask applied to all h heads.
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)
        
        # 1) Do all the linear projections in batch from d_model => h x d_k 
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
        
        # 2) Apply attention on all the projected vectors in batch. 
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        # 3) "Concat" using a view and apply a final linear. 
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)

# %%
class LayerNorm(nn.Module):
    "Construct a layer normalization module."
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
    
class SublayerOutput(nn.Module):
    '''
    A residual connection followed by a layer norm.
    '''
    def __init__(self, size, dropout):
        super(SublayerOutput, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))

# %%
class PositionwiseFeedForward(nn.Module):
    "Positionwise feed-forward network."
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        "Implements FFN equation."
        return self.w_2(self.dropout(F.relu(self.w_1(x))))

# %%
class Encoder(nn.Module):
    '''
    Transformer Encoder
    
    It is a stack of N layers.
    '''
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask=None):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


class EncoderLayer(nn.Module):
    '''
    An encoder layer
    
    Made up of self-attention and a feed forward layer.
    Each of these sublayers have residual and layer norm, implemented by SublayerOutput.
    '''
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer_output = clones(SublayerOutput(size, dropout), 2)
        self.size = size

    def forward(self, x, mask=None):
        "Transformer Encoder"
        x = self.sublayer_output[0](x, lambda x: self.self_attn(x, x, x, mask)) # Encoder self-attention
        return self.sublayer_output[1](x, self.feed_forward)

# %%
def evaluate_model(model, iterator):
    all_preds = []
    all_y = []
    for idx,batch in enumerate(iterator):
        if torch.cuda.is_available():
            x = batch.text.cuda()
        else:
            x = batch.text
        y_pred = model(x)
        predicted = torch.max(y_pred.cpu().data, 1)[1] + 1
        all_preds.extend(predicted.numpy())
        all_y.extend(batch.label.numpy())
    score = accuracy_score(all_y, np.array(all_preds).flatten())
    return score

# %%
class Transformer(nn.Module):
    def __init__(self, config, src_vocab):
        super(Transformer, self).__init__()
        self.config = config
        
        h, N, dropout = self.config.h, self.config.N, self.config.dropout
        d_model, d_ff = self.config.d_model, self.config.d_ff
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        
        self.encoder = Encoder(EncoderLayer(config.d_model, deepcopy(attn), deepcopy(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(config.d_model, src_vocab), deepcopy(position)) # Embeddings followed by PE

        # Fully-Connected Layer
        self.fc = nn.Linear(
            self.config.d_model,
            self.config.output_size
        )
        
        # Softmax non-linearity
        self.softmax = nn.Softmax()

    def forward(self, x):
        embedded_sents = self.src_embed(x.permute(1,0)) # shape = (batch_size, sen_len, d_model)
        encoded_sents = self.encoder(embedded_sents)
        
        # Convert input to (batch_size, d_model) for linear layer
        final_feature_map = encoded_sents[:,-1,:]
        final_out = self.fc(final_feature_map)
        return self.softmax(final_out)
    
    def add_optimizer(self, optimizer):
        self.optimizer = optimizer
        
    def add_loss_op(self, loss_op):
        self.loss_op = loss_op
    
    def reduce_lr(self):
        print("Reducing LR")
        for g in self.optimizer.param_groups:
            g['lr'] = g['lr'] / 2
                
    def run_epoch(self, train_iterator, val_iterator, epoch):
        train_losses = []
        val_accuracies = []
        losses = []
        
        # Reduce learning rate as number of epochs increase
        if (epoch == int(self.config.max_epochs/3)) or (epoch == int(2*self.config.max_epochs/3)):
            self.reduce_lr()
            
        for i, batch in enumerate(train_iterator):
            self.optimizer.zero_grad()
            if torch.cuda.is_available():
                x = batch.text.cuda()
                y = (batch.label - 1).type(torch.cuda.LongTensor)
            else:
                x = batch.text
                y = (batch.label - 1).type(torch.LongTensor)
            y_pred = self.__call__(x)
            loss = self.loss_op(y_pred, y)
            loss.backward()
            losses.append(loss.data.cpu().numpy())
            self.optimizer.step()
    
            if i % 100 == 0:
                print("Iter: {}".format(i+1))
                avg_train_loss = np.mean(losses)
                train_losses.append(avg_train_loss)
                print("\tAverage training loss: {:.5f}".format(avg_train_loss))
                losses = []
                
                # Evalute Accuracy on validation set
                val_accuracy = evaluate_model(self, val_iterator)
                print("\tVal Accuracy: {:.4f}".format(val_accuracy))
                self.train()
                
        return train_losses, val_accuracies

# %% [markdown]
# ## Train and Evaluate

# %%
class Config(object):
    N = 1 # 6 in Transformer Paper
    d_model = 256 # 512 in Transformer Paper
    d_ff = 512 # 2048 in Transformer Paper
    h = 8
    dropout = 0.1
    output_size = 4
    lr = 0.0003
    max_epochs = 35
    batch_size = 128
    max_sen_len = 60

# %%
config = Config()
train_file = '/content/ag_news.train'
test_file = '/content/ag_news.test'

dataset = Dataset(config)
dataset.load_data(train_file, test_file)

# Create Model with specified optimizer and loss function
model = Transformer(config, len(dataset.vocab))
if torch.cuda.is_available():
    model.cuda()
model.train()
optimizer = optim.Adam(model.parameters(), lr=config.lr)
NLLLoss = nn.NLLLoss()
model.add_optimizer(optimizer)
model.add_loss_op(NLLLoss)

train_losses = []
val_accuracies = []

for i in range(config.max_epochs):
    print ("Epoch: {}".format(i))
    train_loss,val_accuracy = model.run_epoch(dataset.train_iterator, dataset.val_iterator, i)
    train_losses.append(train_loss)
    val_accuracies.append(val_accuracy)

train_acc = evaluate_model(model, dataset.train_iterator)
val_acc = evaluate_model(model, dataset.val_iterator)
test_acc = evaluate_model(model, dataset.test_iterator)

print ('Final Training Accuracy: {:.4f}'.format(train_acc))
print ('Final Validation Accuracy: {:.4f}'.format(val_acc))
print ('Final Test Accuracy: {:.4f}'.format(test_acc))
# Out:
# Loaded 96000 training examples
# Loaded 7600 test examples
# Loaded 24000 validation examples
# Epoch: 0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Iter: 1
# 	Average training loss: -0.23047
# 	Val Accuracy: 0.2533
# Iter: 101
# 	Average training loss: -0.26381
# 	Val Accuracy: 0.3369
# Iter: 201
# 	Average training loss: -0.37712
# 	Val Accuracy: 0.4481
# Iter: 301
# 	Average training loss: -0.47484
# 	Val Accuracy: 0.5251
# Iter: 401
# 	Average training loss: -0.53908
# 	Val Accuracy: 0.5816
# Iter: 501
# 	Average training loss: -0.58276
# 	Val Accuracy: 0.6258
# Iter: 601
# 	Average training loss: -0.62815
# 	Val Accuracy: 0.6588
# Iter: 701
# 	Average training loss: -0.66952
# 	Val Accuracy: 0.6909
# Epoch: 1
# Iter: 1
# 	Average training loss: -0.79528
# 	Val Accuracy: 0.6998
# Iter: 101
# 	Average training loss: -0.70107
# 	Val Accuracy: 0.7157
# Iter: 201
# 	Average training loss: -0.71797
# 	Val Accuracy: 0.7292
# Iter: 301
# 	Average training loss: -0.73455
# 	Val Accuracy: 0.7427
# Iter: 401
# 	Average training loss: -0.74260
# 	Val Accuracy: 0.7430
# Iter: 501
# 	Average training loss: -0.75126
# 	Val Accuracy: 0.7568
# Iter: 601
# 	Average training loss: -0.76301
# 	Val Accuracy: 0.7641
# Iter: 701
# 	Average training loss: -0.76782
# 	Val Accuracy: 0.7740
# Epoch: 2
# Iter: 1
# 	Average training loss: -0.78984
# 	Val Accuracy: 0.7818
# Iter: 101
# 	Average training loss: -0.78623
# 	Val Accuracy: 0.7838
# Iter: 201
# 	Average training loss: -0.78971
# 	Val Accuracy: 0.7884
# Iter: 301
# 	Average training loss: -0.79933
# 	Val Accuracy: 0.7894
# Iter: 401
# 	Average training loss: -0.79611
# 	Val Accuracy: 0.7960
# Iter: 501
# 	Average training loss: -0.80372
# 	Val Accuracy: 0.8005
# Iter: 601
# 	Average training loss: -0.80989
# 	Val Accuracy: 0.8050
# Iter: 701
# 	Average training loss: -0.81212
# 	Val Accuracy: 0.8033
# Epoch: 3
# Iter: 1
# 	Average training loss: -0.79631
# 	Val Accuracy: 0.8103
# Iter: 101
# 	Average training loss: -0.81779
# 	Val Accuracy: 0.8137
# Iter: 201
# 	Average training loss: -0.81801
# 	Val Accuracy: 0.8145
# Iter: 301
# 	Average training loss: -0.82175
# 	Val Accuracy: 0.8166
# Iter: 401
# 	Average training loss: -0.82697
# 	Val Accuracy: 0.8217
# Iter: 501
# 	Average training loss: -0.82899
# 	Val Accuracy: 0.8180
# Iter: 601
# 	Average training loss: -0.83120
# 	Val Accuracy: 0.8267
# Iter: 701
# 	Average training loss: -0.82843
# 	Val Accuracy: 0.8262
# Epoch: 4
# Iter: 1
# 	Average training loss: -0.81268
# 	Val Accuracy: 0.8297
# Iter: 101
# 	Average training loss: -0.84039
# 	Val Accuracy: 0.8278
# Iter: 201
# 	Average training loss: -0.84210
# 	Val Accuracy: 0.8239
# Iter: 301
# 	Average training loss: -0.83548
# 	Val Accuracy: 0.8280
# Iter: 401
# 	Average training loss: -0.85216
# 	Val Accuracy: 0.8300
# Iter: 501
# 	Average training loss: -0.84152
# 	Val Accuracy: 0.8301
# Iter: 601
# 	Average training loss: -0.84195
# 	Val Accuracy: 0.8368
# Iter: 701
# 	Average training loss: -0.84702
# 	Val Accuracy: 0.8319
# Epoch: 5
# Iter: 1
# 	Average training loss: -0.88513
# 	Val Accuracy: 0.8367
# Iter: 101
# 	Average training loss: -0.84963
# 	Val Accuracy: 0.8371
# Iter: 201
# 	Average training loss: -0.85142
# 	Val Accuracy: 0.8404
# Iter: 301
# 	Average training loss: -0.85194
# 	Val Accuracy: 0.8326
# Iter: 401
# 	Average training loss: -0.85037
# 	Val Accuracy: 0.8348
# Iter: 501
# 	Average training loss: -0.85780
# 	Val Accuracy: 0.8397
# Iter: 601
# 	Average training loss: -0.85131
# 	Val Accuracy: 0.8437
# Iter: 701
# 	Average training loss: -0.84818
# 	Val Accuracy: 0.8393
# Epoch: 6
# Iter: 1
# 	Average training loss: -0.84478
# 	Val Accuracy: 0.8412
# Iter: 101
# 	Average training loss: -0.85818
# 	Val Accuracy: 0.8449
# Iter: 201
# 	Average training loss: -0.86052
# 	Val Accuracy: 0.8494
# Iter: 301
# 	Average training loss: -0.86073
# 	Val Accuracy: 0.8474
# Iter: 401
# 	Average training loss: -0.86339
# 	Val Accuracy: 0.8478
# Iter: 501
# 	Average training loss: -0.86034
# 	Val Accuracy: 0.8462
# Iter: 601
# 	Average training loss: -0.86126
# 	Val Accuracy: 0.8470
# Iter: 701
# 	Average training loss: -0.85902
# 	Val Accuracy: 0.8465
# Epoch: 7
# Iter: 1
# 	Average training loss: -0.85539
# 	Val Accuracy: 0.8504
# Iter: 101
# 	Average training loss: -0.86763
# 	Val Accuracy: 0.8485
# Iter: 201
# 	Average training loss: -0.86236
# 	Val Accuracy: 0.8510
# Iter: 301
# 	Average training loss: -0.86450
# 	Val Accuracy: 0.8490
# Iter: 401
# 	Average training loss: -0.85883
# 	Val Accuracy: 0.8533
# Iter: 501
# 	Average training loss: -0.86916
# 	Val Accuracy: 0.8525
# Iter: 601
# 	Average training loss: -0.86657
# 	Val Accuracy: 0.8548
# Iter: 701
# 	Average training loss: -0.86773
# 	Val Accuracy: 0.8555
# Epoch: 8
# Iter: 1
# 	Average training loss: -0.93445
# 	Val Accuracy: 0.8558
# Iter: 101
# 	Average training loss: -0.87381
# 	Val Accuracy: 0.8531
# Iter: 201
# 	Average training loss: -0.87015
# 	Val Accuracy: 0.8553
# Iter: 301
# 	Average training loss: -0.86904
# 	Val Accuracy: 0.8585
# Iter: 401
# 	Average training loss: -0.87314
# 	Val Accuracy: 0.8578
# Iter: 501
# 	Average training loss: -0.87385
# 	Val Accuracy: 0.8587
# Iter: 601
# 	Average training loss: -0.87170
# 	Val Accuracy: 0.8524
# Iter: 701
# 	Average training loss: -0.87333
# 	Val Accuracy: 0.8552
# Epoch: 9
# Iter: 1
# 	Average training loss: -0.86359
# 	Val Accuracy: 0.8568
# Iter: 101
# 	Average training loss: -0.87805
# 	Val Accuracy: 0.8605
# Iter: 201
# 	Average training loss: -0.87599
# 	Val Accuracy: 0.8617
# Iter: 301
# 	Average training loss: -0.87669
# 	Val Accuracy: 0.8556
# Iter: 401
# 	Average training loss: -0.87272
# 	Val Accuracy: 0.8609
# Iter: 501
# 	Average training loss: -0.87479
# 	Val Accuracy: 0.8567
# Iter: 601
# 	Average training loss: -0.87407
# 	Val Accuracy: 0.8587
# Iter: 701
# 	Average training loss: -0.87634
# 	Val Accuracy: 0.8588
# Epoch: 10
# Iter: 1
# 	Average training loss: -0.91229
# 	Val Accuracy: 0.8636
# Iter: 101
# 	Average training loss: -0.87728
# 	Val Accuracy: 0.8652
# Iter: 201
# 	Average training loss: -0.88224
# 	Val Accuracy: 0.8638
# Iter: 301
# 	Average training loss: -0.87893
# 	Val Accuracy: 0.8636
# Iter: 401
# 	Average training loss: -0.87745
# 	Val Accuracy: 0.8633
# Iter: 501
# 	Average training loss: -0.87705
# 	Val Accuracy: 0.8615
# Iter: 601
# 	Average training loss: -0.88067
# 	Val Accuracy: 0.8644
# Iter: 701
# 	Average training loss: -0.88188
# 	Val Accuracy: 0.8629
# Epoch: 11
# Reducing LR
# Iter: 1
# 	Average training loss: -0.89659
# 	Val Accuracy: 0.8645
# Iter: 101
# 	Average training loss: -0.88180
# 	Val Accuracy: 0.8664
# Iter: 201
# 	Average training loss: -0.88783
# 	Val Accuracy: 0.8626
# Iter: 301
# 	Average training loss: -0.88121
# 	Val Accuracy: 0.8678
# Iter: 401
# 	Average training loss: -0.88517
# 	Val Accuracy: 0.8666
# Iter: 501
# 	Average training loss: -0.88857
# 	Val Accuracy: 0.8702
# Iter: 601
# 	Average training loss: -0.88457
# 	Val Accuracy: 0.8680
# Iter: 701
# 	Average training loss: -0.89002
# 	Val Accuracy: 0.8705
# Epoch: 12
# Iter: 1
# 	Average training loss: -0.88977
# 	Val Accuracy: 0.8684
# Iter: 101
# 	Average training loss: -0.89228
# 	Val Accuracy: 0.8692
# Iter: 201
# 	Average training loss: -0.89494
# 	Val Accuracy: 0.8682
# Iter: 301
# 	Average training loss: -0.89117
# 	Val Accuracy: 0.8698
# Iter: 401
# 	Average training loss: -0.89131
# 	Val Accuracy: 0.8697
# Iter: 501
# 	Average training loss: -0.88832
# 	Val Accuracy: 0.8710
# Iter: 601
# 	Average training loss: -0.88983
# 	Val Accuracy: 0.8728
# Iter: 701
# 	Average training loss: -0.89233
# 	Val Accuracy: 0.8719
# Epoch: 13
# Iter: 1
# 	Average training loss: -0.89786
# 	Val Accuracy: 0.8708
# Iter: 101
# 	Average training loss: -0.89027
# 	Val Accuracy: 0.8735
# Iter: 201
# 	Average training loss: -0.89448
# 	Val Accuracy: 0.8712
# Iter: 301
# 	Average training loss: -0.89590
# 	Val Accuracy: 0.8720
# Iter: 401
# 	Average training loss: -0.88898
# 	Val Accuracy: 0.8697
# Iter: 501
# 	Average training loss: -0.89491
# 	Val Accuracy: 0.8702
# Iter: 601
# 	Average training loss: -0.89377
# 	Val Accuracy: 0.8720
# Iter: 701
# 	Average training loss: -0.88860
# 	Val Accuracy: 0.8720
# Epoch: 14
# Iter: 1
# 	Average training loss: -0.91692
# 	Val Accuracy: 0.8730
# Iter: 101
# 	Average training loss: -0.89261
# 	Val Accuracy: 0.8704
# Iter: 201
# 	Average training loss: -0.90088
# 	Val Accuracy: 0.8717
# Iter: 301
# 	Average training loss: -0.89535
# 	Val Accuracy: 0.8744
# Iter: 401
# 	Average training loss: -0.89388
# 	Val Accuracy: 0.8740
# Iter: 501
# 	Average training loss: -0.89313
# 	Val Accuracy: 0.8731
# Iter: 601
# 	Average training loss: -0.89374
# 	Val Accuracy: 0.8749
# Iter: 701
# 	Average training loss: -0.89166
# 	Val Accuracy: 0.8730
# Epoch: 15
# Iter: 1
# 	Average training loss: -0.84734
# 	Val Accuracy: 0.8728
# Iter: 101
# 	Average training loss: -0.89464
# 	Val Accuracy: 0.8742
# Iter: 201
# 	Average training loss: -0.89918
# 	Val Accuracy: 0.8787
# Iter: 301
# 	Average training loss: -0.90222
# 	Val Accuracy: 0.8749
# Iter: 401
# 	Average training loss: -0.89582
# 	Val Accuracy: 0.8739
# Iter: 501
# 	Average training loss: -0.89229
# 	Val Accuracy: 0.8726
# Iter: 601
# 	Average training loss: -0.89141
# 	Val Accuracy: 0.8772
# Iter: 701
# 	Average training loss: -0.89620
# 	Val Accuracy: 0.8748
# Epoch: 16
# Iter: 1
# 	Average training loss: -0.93659
# 	Val Accuracy: 0.8738
# Iter: 101
# 	Average training loss: -0.89975
# 	Val Accuracy: 0.8737
# Iter: 201
# 	Average training loss: -0.89612
# 	Val Accuracy: 0.8758
# Iter: 301
# 	Average training loss: -0.89725
# 	Val Accuracy: 0.8768
# Iter: 401
# 	Average training loss: -0.89849
# 	Val Accuracy: 0.8759
# Iter: 501
# 	Average training loss: -0.89874
# 	Val Accuracy: 0.8744
# Iter: 601
# 	Average training loss: -0.89415
# 	Val Accuracy: 0.8737
# Iter: 701
# 	Average training loss: -0.89470
# 	Val Accuracy: 0.8730
# Epoch: 17
# Iter: 1
# 	Average training loss: -0.94530
# 	Val Accuracy: 0.8754
# Iter: 101
# 	Average training loss: -0.90040
# 	Val Accuracy: 0.8770
# Iter: 201
# 	Average training loss: -0.89972
# 	Val Accuracy: 0.8763
# Iter: 301
# 	Average training loss: -0.89754
# 	Val Accuracy: 0.8756
# Iter: 401
# 	Average training loss: -0.90087
# 	Val Accuracy: 0.8758
# Iter: 501
# 	Average training loss: -0.89820
# 	Val Accuracy: 0.8781
# Iter: 601
# 	Average training loss: -0.89676
# 	Val Accuracy: 0.8759
# Iter: 701
# 	Average training loss: -0.90070
# 	Val Accuracy: 0.8760
# Epoch: 18
# Iter: 1
# 	Average training loss: -0.87909
# 	Val Accuracy: 0.8790
# Iter: 101
# 	Average training loss: -0.90213
# 	Val Accuracy: 0.8756
# Iter: 201
# 	Average training loss: -0.89947
# 	Val Accuracy: 0.8761
# Iter: 301
# 	Average training loss: -0.90368
# 	Val Accuracy: 0.8779
# Iter: 401
# 	Average training loss: -0.90278
# 	Val Accuracy: 0.8728
# Iter: 501
# 	Average training loss: -0.90183
# 	Val Accuracy: 0.8773
# Iter: 601
# 	Average training loss: -0.89983
# 	Val Accuracy: 0.8777
# Iter: 701
# 	Average training loss: -0.89785
# 	Val Accuracy: 0.8760
# Epoch: 19
# Iter: 1
# 	Average training loss: -0.92091
# 	Val Accuracy: 0.8757
# Iter: 101
# 	Average training loss: -0.90718
# 	Val Accuracy: 0.8755
# Iter: 201
# 	Average training loss: -0.90664
# 	Val Accuracy: 0.8770
# Iter: 301
# 	Average training loss: -0.89625
# 	Val Accuracy: 0.8750
# Iter: 401
# 	Average training loss: -0.90348
# 	Val Accuracy: 0.8784
# Iter: 501
# 	Average training loss: -0.90200
# 	Val Accuracy: 0.8784
# Iter: 601
# 	Average training loss: -0.90252
# 	Val Accuracy: 0.8793
# Iter: 701
# 	Average training loss: -0.89325
# 	Val Accuracy: 0.8788
# Epoch: 20
# Iter: 1
# 	Average training loss: -0.89709
# 	Val Accuracy: 0.8767
# Iter: 101
# 	Average training loss: -0.90301
# 	Val Accuracy: 0.8793
# Iter: 201
# 	Average training loss: -0.90206
# 	Val Accuracy: 0.8782
# Iter: 301
# 	Average training loss: -0.90483
# 	Val Accuracy: 0.8778
# Iter: 401
# 	Average training loss: -0.89899
# 	Val Accuracy: 0.8798
# Iter: 501
# 	Average training loss: -0.90135
# 	Val Accuracy: 0.8779
# Iter: 601
# 	Average training loss: -0.90343
# 	Val Accuracy: 0.8786
# Iter: 701
# 	Average training loss: -0.90659
# 	Val Accuracy: 0.8767
# Epoch: 21
# Iter: 1
# 	Average training loss: -0.89433
# 	Val Accuracy: 0.8776
# Iter: 101
# 	Average training loss: -0.90423
# 	Val Accuracy: 0.8806
# Iter: 201
# 	Average training loss: -0.90363
# 	Val Accuracy: 0.8789
# Iter: 301
# 	Average training loss: -0.90325
# 	Val Accuracy: 0.8779
# Iter: 401
# 	Average training loss: -0.90614
# 	Val Accuracy: 0.8779
# Iter: 501
# 	Average training loss: -0.90908
# 	Val Accuracy: 0.8798
# Iter: 601
# 	Average training loss: -0.89807
# 	Val Accuracy: 0.8767
# Iter: 701
# 	Average training loss: -0.90645
# 	Val Accuracy: 0.8802
# Epoch: 22
# Iter: 1
# 	Average training loss: -0.90822
# 	Val Accuracy: 0.8773
# Iter: 101
# 	Average training loss: -0.90806
# 	Val Accuracy: 0.8796
# Iter: 201
# 	Average training loss: -0.90795
# 	Val Accuracy: 0.8825
# Iter: 301
# 	Average training loss: -0.90333
# 	Val Accuracy: 0.8788
# Iter: 401
# 	Average training loss: -0.90346
# 	Val Accuracy: 0.8797
# Iter: 501
# 	Average training loss: -0.90497
# 	Val Accuracy: 0.8812
# Iter: 601
# 	Average training loss: -0.90453
# 	Val Accuracy: 0.8799
# Iter: 701
# 	Average training loss: -0.90674
# 	Val Accuracy: 0.8794
# Epoch: 23
# Reducing LR
# Iter: 1
# 	Average training loss: -0.89081
# 	Val Accuracy: 0.8790
# Iter: 101
# 	Average training loss: -0.90566
# 	Val Accuracy: 0.8826
# Iter: 201
# 	Average training loss: -0.90743
# 	Val Accuracy: 0.8812
# Iter: 301
# 	Average training loss: -0.91258
# 	Val Accuracy: 0.8826
# Iter: 401
# 	Average training loss: -0.90835
# 	Val Accuracy: 0.8816
# Iter: 501
# 	Average training loss: -0.90661
# 	Val Accuracy: 0.8818
# Iter: 601
# 	Average training loss: -0.91042
# 	Val Accuracy: 0.8815
# Iter: 701
# 	Average training loss: -0.90784
# 	Val Accuracy: 0.8812
# Epoch: 24
# Iter: 1
# 	Average training loss: -0.87072
# 	Val Accuracy: 0.8809
# Iter: 101
# 	Average training loss: -0.90772
# 	Val Accuracy: 0.8821
# Iter: 201
# 	Average training loss: -0.90233
# 	Val Accuracy: 0.8807
# Iter: 301
# 	Average training loss: -0.90780
# 	Val Accuracy: 0.8815
# Iter: 401
# 	Average training loss: -0.91124
# 	Val Accuracy: 0.8821
# Iter: 501
# 	Average training loss: -0.90977
# 	Val Accuracy: 0.8814
# Iter: 601
# 	Average training loss: -0.91198
# 	Val Accuracy: 0.8812
# Iter: 701
# 	Average training loss: -0.90736
# 	Val Accuracy: 0.8805
# Epoch: 25
# Iter: 1
# 	Average training loss: -0.91231
# 	Val Accuracy: 0.8804
# Iter: 101
# 	Average training loss: -0.91121
# 	Val Accuracy: 0.8821
# Iter: 201
# 	Average training loss: -0.90996
# 	Val Accuracy: 0.8834
# Iter: 301
# 	Average training loss: -0.91401
# 	Val Accuracy: 0.8812
# Iter: 401
# 	Average training loss: -0.90479
# 	Val Accuracy: 0.8825
# Iter: 501
# 	Average training loss: -0.90381
# 	Val Accuracy: 0.8829
# Iter: 601
# 	Average training loss: -0.90572
# 	Val Accuracy: 0.8812
# Iter: 701
# 	Average training loss: -0.90966
# 	Val Accuracy: 0.8830
# Epoch: 26
# Iter: 1
# 	Average training loss: -0.93501
# 	Val Accuracy: 0.8820
# Iter: 101
# 	Average training loss: -0.91075
# 	Val Accuracy: 0.8838
# Iter: 201
# 	Average training loss: -0.91485
# 	Val Accuracy: 0.8830
# Iter: 301
# 	Average training loss: -0.91315
# 	Val Accuracy: 0.8843
# Iter: 401
# 	Average training loss: -0.90371
# 	Val Accuracy: 0.8844
# Iter: 501
# 	Average training loss: -0.91075
# 	Val Accuracy: 0.8839
# Iter: 601
# 	Average training loss: -0.91290
# 	Val Accuracy: 0.8851
# Iter: 701
# 	Average training loss: -0.91000
# 	Val Accuracy: 0.8821
# Epoch: 27
# Iter: 1
# 	Average training loss: -0.94641
# 	Val Accuracy: 0.8832
# Iter: 101
# 	Average training loss: -0.90521
# 	Val Accuracy: 0.8835
# Iter: 201
# 	Average training loss: -0.91598
# 	Val Accuracy: 0.8826
# Iter: 301
# 	Average training loss: -0.91082
# 	Val Accuracy: 0.8818
# Iter: 401
# 	Average training loss: -0.90848
# 	Val Accuracy: 0.8827
# Iter: 501
# 	Average training loss: -0.91229
# 	Val Accuracy: 0.8828
# Iter: 601
# 	Average training loss: -0.90721
# 	Val Accuracy: 0.8844
# Iter: 701
# 	Average training loss: -0.90878
# 	Val Accuracy: 0.8840
# Epoch: 28
# Iter: 1
# 	Average training loss: -0.85524
# 	Val Accuracy: 0.8825
# Iter: 101
# 	Average training loss: -0.91383
# 	Val Accuracy: 0.8837
# Iter: 201
# 	Average training loss: -0.91223
# 	Val Accuracy: 0.8837
# Iter: 301
# 	Average training loss: -0.90877
# 	Val Accuracy: 0.8839
# Iter: 401
# 	Average training loss: -0.91505
# 	Val Accuracy: 0.8828
# Iter: 501
# 	Average training loss: -0.90920
# 	Val Accuracy: 0.8828
# Iter: 601
# 	Average training loss: -0.91228
# 	Val Accuracy: 0.8845
# Iter: 701
# 	Average training loss: -0.91199
# 	Val Accuracy: 0.8844
# Epoch: 29
# Iter: 1
# 	Average training loss: -0.88190
# 	Val Accuracy: 0.8844
# Iter: 101
# 	Average training loss: -0.91126
# 	Val Accuracy: 0.8846
# Iter: 201
# 	Average training loss: -0.91299
# 	Val Accuracy: 0.8859
# Iter: 301
# 	Average training loss: -0.91138
# 	Val Accuracy: 0.8836
# Iter: 401
# 	Average training loss: -0.91218
# 	Val Accuracy: 0.8845
# Iter: 501
# 	Average training loss: -0.91218
# 	Val Accuracy: 0.8839
# Iter: 601
# 	Average training loss: -0.91161
# 	Val Accuracy: 0.8845
# Iter: 701
# 	Average training loss: -0.91066
# 	Val Accuracy: 0.8838
# Epoch: 30
# Iter: 1
# 	Average training loss: -0.93607
# 	Val Accuracy: 0.8826
# Iter: 101
# 	Average training loss: -0.91538
# 	Val Accuracy: 0.8828
# Iter: 201
# 	Average training loss: -0.91262
# 	Val Accuracy: 0.8826
# Iter: 301
# 	Average training loss: -0.91391
# 	Val Accuracy: 0.8851
# Iter: 401
# 	Average training loss: -0.91072
# 	Val Accuracy: 0.8840
# Iter: 501
# 	Average training loss: -0.91447
# 	Val Accuracy: 0.8857
# Iter: 601
# 	Average training loss: -0.90959
# 	Val Accuracy: 0.8827
# Iter: 701
# 	Average training loss: -0.91282
# 	Val Accuracy: 0.8852
# Epoch: 31
# Iter: 1
# 	Average training loss: -0.93480
# 	Val Accuracy: 0.8856
# Iter: 101
# 	Average training loss: -0.91370
# 	Val Accuracy: 0.8840
# Iter: 201
# 	Average training loss: -0.91465
# 	Val Accuracy: 0.8853
# Iter: 301
# 	Average training loss: -0.91601
# 	Val Accuracy: 0.8852
# Iter: 401
# 	Average training loss: -0.91403
# 	Val Accuracy: 0.8849
# Iter: 501
# 	Average training loss: -0.91406
# 	Val Accuracy: 0.8847
# Iter: 601
# 	Average training loss: -0.90984
# 	Val Accuracy: 0.8855
# Iter: 701
# 	Average training loss: -0.91393
# 	Val Accuracy: 0.8854
# Epoch: 32
# Iter: 1
# 	Average training loss: -0.92922
# 	Val Accuracy: 0.8849
# Iter: 101
# 	Average training loss: -0.91346
# 	Val Accuracy: 0.8853
# Iter: 201
# 	Average training loss: -0.91338
# 	Val Accuracy: 0.8849
# Iter: 301
# 	Average training loss: -0.91311
# 	Val Accuracy: 0.8852
# Iter: 401
# 	Average training loss: -0.91399
# 	Val Accuracy: 0.8843
# Iter: 501
# 	Average training loss: -0.91404
# 	Val Accuracy: 0.8851
# Iter: 601
# 	Average training loss: -0.91447
# 	Val Accuracy: 0.8865
# Iter: 701
# 	Average training loss: -0.91451
# 	Val Accuracy: 0.8878
# Epoch: 33
# Iter: 1
# 	Average training loss: -0.87171
# 	Val Accuracy: 0.8859
# Iter: 101
# 	Average training loss: -0.91696
# 	Val Accuracy: 0.8850
# Iter: 201
# 	Average training loss: -0.91580
# 	Val Accuracy: 0.8862
# Iter: 301
# 	Average training loss: -0.91117
# 	Val Accuracy: 0.8864
# Iter: 401
# 	Average training loss: -0.91280
# 	Val Accuracy: 0.8835
# Iter: 501
# 	Average training loss: -0.91515
# 	Val Accuracy: 0.8850
# Iter: 601
# 	Average training loss: -0.91667
# 	Val Accuracy: 0.8877
# Iter: 701
# 	Average training loss: -0.91566
# 	Val Accuracy: 0.8840
# Epoch: 34
# Iter: 1
# 	Average training loss: -0.87635
# 	Val Accuracy: 0.8848
# Iter: 101
# 	Average training loss: -0.91545
# 	Val Accuracy: 0.8861
# Iter: 201
# 	Average training loss: -0.91316
# 	Val Accuracy: 0.8852
# Iter: 301
# 	Average training loss: -0.91417
# 	Val Accuracy: 0.8843
# Iter: 401
# 	Average training loss: -0.91368
# 	Val Accuracy: 0.8835
# Iter: 501
# 	Average training loss: -0.91394
# 	Val Accuracy: 0.8844
# Iter: 601
# 	Average training loss: -0.91910
# 	Val Accuracy: 0.8840
# Iter: 701
# 	Average training loss: -0.91599
# 	Val Accuracy: 0.8840
# Final Training Accuracy: 0.9143
# Final Validation Accuracy: 0.8844
# Final Test Accuracy: 0.8774
